# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathigaasm/cseb/blob/main/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy matplotlib pillow

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = Image.open("/content/swathii.jpg")

# %%
image_array = np.array(image)

# %%
plt.imshow(image_array)
plt.title("Original image")
plt.axis('off')
plt.show()

# %% [markdown]
# convert to grayscale black and white

# %%
gray_array = image_array.mean(axis=2).astype(np.uint8)
plt.imshow(gray_array, cmap='gray')
plt.title("Grayscale image")
plt.axis('off')
plt.show()
